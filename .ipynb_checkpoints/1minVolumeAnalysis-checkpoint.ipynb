# %%
# this program analyzes stock news
    # every minute, the API gets the most recent stock news
    # the stock is then analyzed to see if it is worth buying
    # it uses data from the stockRegression.py file to decide, including volume and float analysis

# API key for data = d7c3bb0b67da3ace468bb315d918e92b


try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

import certifi
import json

def get_jsonparsed_data(url):
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

def getInfo(symbol):
    URLWithTicker = "https://financialmodelingprep.com/api/v3/profile/" + symbol + "?apikey=d7c3bb0b67da3ace468bb315d918e92b"
    url = (URLWithTicker)
    dataList = get_jsonparsed_data(url)
    if dataList == []:
        print("no data exists for ticker")
    
    else:         
        finalList = dataList[0]
        print("\n\nthe symbol is:", finalList['symbol'])
        print("the average volume is:", finalList['volAvg'])
        print("the market cap is:", finalList['mktCap'])
        print("the price is:", finalList['price'])
        print("the beta is:", finalList['beta'])

    URLWithTicker2 = "https://financialmodelingprep.com/api/v4/shares_float?symbol=" + symbol + "&apikey=d7c3bb0b67da3ace468bb315d918e92b"
    url = (URLWithTicker2)
    dataList = get_jsonparsed_data(url)
    if dataList == []:
        print("no data exists for ticker")
    else:
        finalList = dataList[0]
        print("\nthe free float is:", finalList['freeFloat'])
        print("the float shares are:", finalList['floatShares'])
        print("the outstanding shares are:", finalList['outstandingShares'])

    URLWithTicker3 = "https://financialmodelingprep.com/api/v3/technical_indicator/1min/" + symbol + "?period=10&type=ema&apikey=d7c3bb0b67da3ace468bb315d918e92b"
    url = (URLWithTicker3)
    dataList = get_jsonparsed_data(url)
    if dataList == []:
        print("no data exists for ticker")
        
    else:
        finalList = dataList[0]
        print("\ndate :", finalList['date'])
        print("open :", finalList['open'])
        print("high :", finalList['high'])
        print("low ", finalList['low'])
        print("close :", finalList['close'])
        print("volume:", finalList['volume'])
        print("ema :", finalList['ema'])

    
def getNews(newsNum):
    newsNumber = str(newsNum)
    url = ("https://financialmodelingprep.com/api/v3/stock_news?limit="+newsNumber+"&apikey=d7c3bb0b67da3ace468bb315d918e92b")
    dataList = get_jsonparsed_data(url)
    
    x = 0
    while x <= newsNum-1:
        finalList = dataList[x]
        getInfo(finalList['symbol'])
        print("\ndate :", finalList['publishedDate'])
        print("symbol :", finalList['symbol'])
        print("title :", finalList['title'])
        print("text :", finalList['text'])
        x = x + 1
    
    
    

newsNum = 5
news = getNews(newsNum)
print(news)

        
    # live testing
        # when news drops
            # check float of stock
            # check keyword phrase
            # check market conditions
            # check 1 minute volume compared to average 1 minute volume 
            # give each of these weights based off of regression analysis on imporance of these influencing the price
            # if float<x & keyword phrase=? & market%inc=? & volumeSpike>x%average
# Out:
# the symbol is: HNST
# the average volume is: 1408940
# the market cap is: 566417280
# the price is: 6.04
# the beta is: 0.0
#
# the free float is: 62.23699444622264
# the float shares are: 56653400.0
# the outstanding shares are: 91028496.0
#
# date : 2022-03-24 16:00:00
# open : 6.04
# high : 6.04
# low  6.04
# close : 6.04
# volume: 2399.0
# ema : 6.035452508818352
#
# date : 2022-03-24 17:11:00
# symbol : HNST
# title : Earnings Results: Honest stock falls more than 14% as sales of hand sanitizers, masks drop
# text : Honest Co. stock fell more than 14% in the extended session Thursday after the consumer products company founded by entrepreneur and actress Jessica Alba saw a wider-than-expected quarterly loss, thanks in part to a steep drop in sales of masks and sanitizing products it had introduced earlier in the pandemic.
#
#
# the symbol is: VECO
# the average volume is: 485934
# the market cap is: 1461857152
# the price is: 28.86
# the beta is: 1.337106
#
# the free float is: 97.7850055475052
# the float shares are: 49531430.0
# the outstanding shares are: 50653400.0
#
# date : 2022-03-24 16:00:00
# open : 28.86
# high : 28.86
# low  28.86
# close : 28.86
# volume: 20840.0
# ema : 28.81063414453921
#
# date : 2022-03-24 17:08:18
# symbol : VECO
# title : Top Semiconductor Stocks To Watch Before April 2022
# text : Should investors be paying more attention to semiconductor stocks?
#
#
# the symbol is: TLRY
# the average volume is: 21671121
# the market cap is: 3350646272
# the price is: 6.97
# the beta is: 2.619801
#
# the free float is: 93.15526580740716
# the float shares are: 447819720.0
# the outstanding shares are: 480724000.0
#
# date : 2022-03-24 16:00:00
# open : 7.0
# high : 7.09
# low  6.97
# close : 7.04
# volume: 157829.0
# ema : 6.9699449196406364
#
# date : 2022-03-24 17:07:07
# symbol : TLRY
# title : Why Marijuana Stocks Lit Up on Thursday
# text : For only the second time ever, cannabis legalization will get a floor vote in Congress.
#
#
# the symbol is: CLVR
# the average volume is: 349306
# the market cap is: 42938080
# the price is: 1.58
# the beta is: 0.510278
#
# the free float is: 46.785713221323995
# the float shares are: 12558689.0
# the outstanding shares are: 26843000.0
#
# date : 2022-03-24 15:59:00
# open : 1.5892
# high : 1.59
# low  1.5648
# close : 1.58
# volume: 8631.0
# ema : 1.6069413692067545
#
# date : 2022-03-24 17:06:03
# symbol : CLVR
# title : Here's Why Cannabis-Related Stock Clever Leaves Is Rising During Thursday's After-Hours Session
# text : Clever Leaves Holdings Inc (NASDAQ: CLVR) shares are trading higher by 9.5% to $1.73 during Thursday's after-hours session after the company reported better-than-expected fourth-quarter sales results and reaffirmed FY22 guidance. Clever Leaves Holdings reported quarterly sales of $4.
#
#
# the symbol is: AMSF
# the average volume is: 97526
# the market cap is: 956392896
# the price is: 49.39
# the beta is: 0.37746
#
# the free float is: 98.08135673746779
# the float shares are: 18992572.0
# the outstanding shares are: 19364100.0
#
# date : 2022-03-24 16:00:00
# open : 49.39
# high : 49.39
# low  49.39
# close : 49.39
# volume: 1131.0
# ema : 49.307648678771905
#
# date : 2022-03-24 17:00:00
# symbol : AMSF
# title : AMERISAFE Announces 2022 First Quarter Earnings Release and Conference Call Schedule
# text : DERIDDER, La.--(BUSINESS WIRE)--AMERISAFE ANNOUNCES FIRST QUARTER EARNINGS SCHEDULE
# None
